# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('world_population.csv'
           )
df.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df = df.replace([np.inf, -np.inf], np.nan)

# %%
df.dropna(inplace=True)

# %% [markdown]
# # Visualize

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
sns.histplot(df,x='2022 Population',hue='Continent',bins=10)
plt.show()
# Out:
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(df,x='2020 Population',hue='Continent',bins=40)
plt.show()
# Out:
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(20,5))
sns.kdeplot(df,x='2022 Population',hue='Continent',gridsize=5,fill=True,log_scale=True)
plt.show()
# Out:
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(20,5))
sns.kdeplot(df,x='2020 Population',hue='Continent',gridsize=500,fill=True,log_scale=True)
plt.show()
# Out:
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(20,5))
sns.kdeplot(df,x='2015 Population',hue='Continent',gridsize=500,fill=True,log_scale=True)
plt.show()
# Out:
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(20,5))
sns.kdeplot(df,x='2010 Population',hue='Continent',gridsize=500,fill=True,log_scale=True)
plt.show()
# Out:
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(20,5))
sns.barplot(df,x='2010 Population',y='Continent',)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(df,x='2020 Population',y='Continent',)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(df,x='2015 Population',y='Continent',)
plt.show()

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
plt.figure(figsize=(20,5))
sns.barplot(df,x='Continent',y='2010 Population',hue='Continent',width=1.5)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(df,x='Continent',y='2020 Population',hue='Continent',width=1.2)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(df,x='Continent',y='2015 Population',hue='Continent',width=1.2)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(df,x='Continent',y='1990 Population',hue='Continent')
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.pairplot(df,hue='Continent')
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.boxplot(df,x='Growth Rate',y='Continent')
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(df,x='Area (km²)',y='Continent')
plt.show()

# %%
corr = df.select_dtypes('number').corr()

# %%
plt.figure(figsize=(20,5))
sns.heatmap(corr,annot=True,fmt='.3g')
plt.show()

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(df,x='Growth Rate',y='Area (km²)',hue='Continent')
plt.show()
# Out:
# <Axes: xlabel='Growth Rate', ylabel='Area (km²)'>

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(df,x='Growth Rate',y='World Population Percentage',hue='Continent')
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(df,x='2022 Population',y='Area (km²)',hue='Continent',size='Continent')
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(df,x='1970 Population',y='Area (km²)',hue='Continent',style='Continent')
plt.show()
